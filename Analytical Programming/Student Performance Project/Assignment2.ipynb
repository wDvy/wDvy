# %% [markdown]
# # Assignment 2

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('StudentsPerformance.csv')

# %%
#Part 2

scoreavgs = pd.Series()

for x in range(len(data)):
    savg = np.average(data.iloc[x:x+1,5:])
    scoreavgs[x] = savg

data["Score Averages"] = round(scoreavgs, 2)
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# Part 2 

#Test prep Course, this commented out one works, but is completely unnessicary lol.
'''
completed = pd.Series()
notCompleted = pd.Series()
y = 0 
z = 0

for x in range(len(data)):
    if data["test preparation course"][x] == "completed":
        completed[y] = data["Score Averages"][x]
        y += 1
    else:
        notCompleted[z] = data["Score Averages"][x]
        z += 1
        pass
# 'do not need to store in table:'
print(f'completed practice  avg: {round(np.average(completed),2)}')
print(f'not completed practice  avg: {round(np.average(notCompleted),2)}')
'''

print(round(data.groupby("test preparation course")["Score Averages"].mean(),2))
print()

# Parnetal Level of education
print(round(data.groupby("parental level of education")['Score Averages'].mean(),2))
# Out:
# test preparation course
# completed    72.67
# none         65.04
# Name: Score Averages, dtype: float64
#
# parental level of education
# associate's degree    69.57
# bachelor's degree     71.92
# high school           63.10
# master's degree       73.60
# some college          68.48
# some high school      65.11
# Name: Score Averages, dtype: float64

# %%
grades = ['A','B','C','D']
thresholds = [90,80,70,60]

gd = pd.Series()


for x in range(len(data)):
    if data["Score Averages"][x] >= 90: gd[x] = 'A'
    elif data["Score Averages"][x] >= 80: gd[x] = 'B'
    elif data["Score Averages"][x] >= 70: gd[x] = 'C'
    elif data["Score Averages"][x] >= 60: gd[x] = 'D'
    else: gd[x] = 'F'
    
data["Grades"] = gd

malegroup = data.query('gender == "male"')
femalegroup = data.query('gender == "female"')

print("Male Group")
print(malegroup.groupby('Grades').count()['gender'])

print()

print("Female Group")
print(femalegroup.groupby('Grades').count()['gender'])
# Out:
# Male Group
# Grades
# A     14
# B     66
# C    111
# D    130
# F    161
# Name: gender, dtype: int64
#
# Female Group
# Grades
# A     38
# B     80
# C    150
# D    126
# F    124
# Name: gender, dtype: int64

# %%
#part 4
data.to_json(r'desktop/file.json')
